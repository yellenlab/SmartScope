# %% [markdown]
# ## Alignment Mark Model Training
#
# Make sure that the paths below are correct before continuing

# %%
# Path to the json file created by Labelbox
JSON_PATH = 'labels.json'
# path to the fodler containing the trainig images 
dataset_path = 'C:\\Users\\cell_ml\\Downloads\\images'
# name of generated model
model_path = "alignment_50_v2.h5"

# %%
import os
import sys
import random
import math
import re
import time
import numpy as np
import cv2
import matplotlib
import matplotlib.pyplot as plt
import json
import pandas as pd

from skimage.io import imread, imshow, imread_collection, concatenate_images
import skimage.draw

from smartscope.source.maskrcnn import utils
from smartscope.source.maskrcnn import model as modellib
from smartscope.source.maskrcnn import visualize
from smartscope.source.maskrcnn.config import Config
from smartscope.source.maskrcnn.model import log

# %matplotlib inline 

# Root directory of the project
ROOT_DIR = os.getcwd()

# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

# Local path to trained weights file
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")
# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)
# Out:
# Using TensorFlow backend.
# Downloading pretrained model to C:\Users\cell_ml\Documents\SmartScope_v2\SmartScope\smartscope\notebook\training\mask_rcnn_coco.h5 ...
# ... done downloading pretrained model!

# %%
# Split the labels into training and validation subsets
annotations = json.load(open('labels.json', 'r'))
number_of_annotations = len(annotations)
# Use 4/5ths of the data for training and 1/5 for validation
split_at = number_of_annotations * 4/5
training_data = []
val_data = []
for i, a in enumerate(annotations):
    if i < split_at:
        training_data.append(a)
    else:
        val_data.append(a)

with open('train.json', 'w+') as trainfile:
    json.dump(training_data, trainfile)
with open('val.json', 'w+') as valfile:
    json.dump(val_data, valfile)

# %%
class MarkConfig(Config):
    """Configuration for training on the cell dataset.
    Derives from the base Config class and overrides some values.
    """
    # Give the configuration a recognizable name
    NAME = "mark"

    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

    # Number of classes (including background)
    NUM_CLASSES = 1 + 1  # Background + cell

    # Number of training steps per epoch
    STEPS_PER_EPOCH = 150
    
    # set validation steps 
    VALIDATION_STEPS = 50
    
    # Skip detections with < 90% confidence
    DETECTION_MIN_CONFIDENCE = 0.9

config = MarkConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.9
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           mark
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                150
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %%
def get_ax(rows=1, cols=1, size=8):
    """Return a Matplotlib Axes array to be used in
    all visualizations in the notebook. Provide a
    central point to control graph sizes.
    
    Change the default size attribute to control the size
    of rendered images
    """
    _, ax = plt.subplots(rows, cols, figsize=(size*cols, size*rows))
    return ax

# %%
class MarkDataset(utils.Dataset):

    def load_shapes(self, subset):
        # Add classes. We have only one class to add.
        self.add_class("Mark", 1, "Mark")

        # Train or validation dataset?
        dataset_dir = dataset_path
        
        if subset == 'train':
            annotations = json.load(open('train.json', 'r'))
        else:
            annotations = json.load(open('val.json', 'r'))
        
        # Add images annotated with Labelbox 
        for a in annotations:
            print(a['Label'])
            if 'Mark' in a['Label']:
                polys = [r['geometry'] for r in a['Label']['Mark']] 
                polygons = []

                for i, p in enumerate(polys):
                    x_points = [x['x'] for x in p]
                    y_points = [y['y'] for y in p]
                    polygons.append({'all_points_x': x_points, 'all_points_y': y_points})

                # Get Image Size 
                image_path = os.path.join(dataset_dir, a['External ID'])
                image = imread(image_path)
                height, width = image.shape[:2]

                self.add_image(
                    "Mark",
                    image_id=a['External ID'],  # use file name as a unique image id
                    path=image_path,
                    width=width, height=height,
                    polygons=polygons)
        
    def load_mask(self, image_id):
        """Generate instance masks for an image.
       Returns:
        masks: A bool array of shape [height, width, instance count] with
            one mask per instance.
        class_ids: a 1D array of class IDs of the instance masks.
        """
        # If not a balloon dataset image, delegate to parent class.
        image_info = self.image_info[image_id]
        if image_info["source"] != "Mark":
            return super(self.__class__, self).load_mask(image_id)

        # Convert polygons to a bitmap mask of shape
        # [height, width, instance_count]
        info = self.image_info[image_id]
        mask = np.zeros([info["height"], info["width"], len(info["polygons"])],
                        dtype=np.uint8)
        for i, p in enumerate(info["polygons"]):
            # Get indexes of pixels inside the polygon and set them to 1
            rr, cc = skimage.draw.polygon(p['all_points_y'], p['all_points_x'])
            mask[rr, cc, i] = 1

        # Return mask, and array of class IDs of each instance. Since we have
        # one class ID only, we return an array of 1s
        return mask.astype(np.bool), np.ones([mask.shape[-1]], dtype=np.int32)

    def image_reference(self, image_id):
        """Return the path of the image."""
        info = self.image_info[image_id]
        if info["source"] == "Mark":
            return info["path"]
        else:
            super(self.__class__, self).image_reference(image_id)

# %%
# Training dataset
dataset_train = MarkDataset()
dataset_train.load_shapes("train")
dataset_train.prepare()


# Validation dataset
dataset_val = MarkDataset()
dataset_val.load_shapes("val")
dataset_val.prepare()

# %%
# Load and display random samples
image_ids = np.random.choice(dataset_train.image_ids, 4)
for image_id in image_ids:
    image = dataset_train.load_image(image_id)
    mask, class_ids = dataset_train.load_mask(image_id)
    visualize.display_top_masks(image, mask, class_ids, dataset_train.class_names)

# %%
# Create model in training mode
model = modellib.MaskRCNN(mode="training", config=config,
                          model_dir=MODEL_DIR)
# Out:
# WARNING:tensorflow:From C:\Users\cell_ml\Miniconda3\envs\smartscope\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
# Which weights to start with?
init_with = "coco"  # imagenet, coco, or last

if init_with == "imagenet":
    model.load_weights(model.get_imagenet_weights(), by_name=True)
elif init_with == "coco":
    # Load weights trained on MS COCO, but skip layers that
    # are different due to the different number of classes
    # See README for instructions to download the COCO weights
    model.load_weights(COCO_MODEL_PATH, by_name=True,
                       exclude=["mrcnn_class_logits", "mrcnn_bbox_fc", 
                                "mrcnn_bbox", "mrcnn_mask"])
elif init_with == "last":
    # Load the last model you trained and continue training
    model.load_weights(model.find_last()[1], by_name=True)

# %%
# Train the head branches
# Passing layers="heads" freezes all layers except the head
# layers. You can also pass a regular expression to select
# which layers to train by name pattern.
model.train(dataset_train, dataset_val,
            learning_rate=config.LEARNING_RATE, 
            epochs=1, 
            layers='heads')
# Out:
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: C:\Users\cell_ml\Documents\SmartScope_v2\SmartScope\smartscope\notebook\training\logs\mark20190823T1153\mask_rcnn_mark_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# WARNING:tensorflow:From C:\Users\cell_ml\Miniconda3\envs\smartscope\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# C:\Users\cell_ml\Miniconda3\envs\smartscope\lib\site-packages\tensorflow\python\ops\gradients_impl.py:110: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/1
# 150/150 [==============================] - 237s 2s/step - loss: 2.6410 - rpn_class_loss: 0.1069 - rpn_bbox_loss: 1.3880 - mrcnn_class_loss: 0.0433 - mrcnn_bbox_loss: 0.6522 - mrcnn_mask_loss: 0.4506 - val_loss: 1.6100 - val_rpn_class_loss: 0.0356 - val_rpn_bbox_loss: 0.6755 - val_mrcnn_class_loss: 0.0140 - val_mrcnn_bbox_loss: 0.4343 - val_mrcnn_mask_loss: 0.4505

# %%
# Fine tune all layers
# Passing layers="all" trains all layers. You can also 
# pass a regular expression to select which layers to
# train by name pattern.
model.train(dataset_train, dataset_val, 
            learning_rate=config.LEARNING_RATE / 10,
            epochs=50, 
            layers="all")

model.keras_model.save_weights(model_path)
# Out:
# Starting at epoch 3. LR=0.0001
#
# Checkpoint Path: /home/caleb/Dropbox/ComputerVisionResearch/Alignment_Marks/logs/mark20190627T1525/mask_rcnn_mark_{epoch:04d}.h5
# Selecting layers to train
# conv1                  (Conv2D)
# bn_conv1               (BatchNorm)
# res2a_branch2a         (Conv2D)
# bn2a_branch2a          (BatchNorm)
# res2a_branch2b         (Conv2D)
# bn2a_branch2b          (BatchNorm)
# res2a_branch2c         (Conv2D)
# res2a_branch1          (Conv2D)
# bn2a_branch2c          (BatchNorm)
# bn2a_branch1           (BatchNorm)
# res2b_branch2a         (Conv2D)
# bn2b_branch2a          (BatchNorm)
# res2b_branch2b         (Conv2D)
# bn2b_branch2b          (BatchNorm)
# res2b_branch2c         (Conv2D)
# bn2b_branch2c          (BatchNorm)
# res2c_branch2a         (Conv2D)
# bn2c_branch2a          (BatchNorm)
# res2c_branch2b         (Conv2D)
# bn2c_branch2b          (BatchNorm)
# res2c_branch2c         (Conv2D)
# bn2c_branch2c          (BatchNorm)
# res3a_branch2a         (Conv2D)
# bn3a_branch2a          (BatchNorm)
# res3a_branch2b         (Conv2D)
# bn3a_branch2b          (BatchNorm)
# res3a_branch2c         (Conv2D)
# res3a_branch1          (Conv2D)
# bn3a_branch2c          (BatchNorm)
# bn3a_branch1           (BatchNorm)
# res3b_branch2a         (Conv2D)
# bn3b_branch2a          (BatchNorm)
# res3b_branch2b         (Conv2D)
# bn3b_branch2b          (BatchNorm)
# res3b_branch2c         (Conv2D)
# bn3b_branch2c          (BatchNorm)
# res3c_branch2a         (Conv2D)
# bn3c_branch2a          (BatchNorm)
# res3c_branch2b         (Conv2D)
# bn3c_branch2b          (BatchNorm)
# res3c_branch2c         (Conv2D)
# bn3c_branch2c          (BatchNorm)
# res3d_branch2a         (Conv2D)
# bn3d_branch2a          (BatchNorm)
# res3d_branch2b         (Conv2D)
# bn3d_branch2b          (BatchNorm)
# res3d_branch2c         (Conv2D)
# bn3d_branch2c          (BatchNorm)
# res4a_branch2a         (Conv2D)
# bn4a_branch2a          (BatchNorm)
# res4a_branch2b         (Conv2D)
# bn4a_branch2b          (BatchNorm)
# res4a_branch2c         (Conv2D)
# res4a_branch1          (Conv2D)
# bn4a_branch2c          (BatchNorm)
# bn4a_branch1           (BatchNorm)
# res4b_branch2a         (Conv2D)
# bn4b_branch2a          (BatchNorm)
# res4b_branch2b         (Conv2D)
# bn4b_branch2b          (BatchNorm)
# res4b_branch2c         (Conv2D)
# bn4b_branch2c          (BatchNorm)
# res4c_branch2a         (Conv2D)
# bn4c_branch2a          (BatchNorm)
# res4c_branch2b         (Conv2D)
# bn4c_branch2b          (BatchNorm)
# res4c_branch2c         (Conv2D)
# bn4c_branch2c          (BatchNorm)
# res4d_branch2a         (Conv2D)
# bn4d_branch2a          (BatchNorm)
# res4d_branch2b         (Conv2D)
# bn4d_branch2b          (BatchNorm)
# res4d_branch2c         (Conv2D)
# bn4d_branch2c          (BatchNorm)
# res4e_branch2a         (Conv2D)
# bn4e_branch2a          (BatchNorm)
# res4e_branch2b         (Conv2D)
# bn4e_branch2b          (BatchNorm)
# res4e_branch2c         (Conv2D)
# bn4e_branch2c          (BatchNorm)
# res4f_branch2a         (Conv2D)
# bn4f_branch2a          (BatchNorm)
# res4f_branch2b         (Conv2D)
# bn4f_branch2b          (BatchNorm)
# res4f_branch2c         (Conv2D)
# bn4f_branch2c          (BatchNorm)
# res4g_branch2a         (Conv2D)
# bn4g_branch2a          (BatchNorm)
# res4g_branch2b         (Conv2D)
# bn4g_branch2b          (BatchNorm)
# res4g_branch2c         (Conv2D)
# bn4g_branch2c          (BatchNorm)
# res4h_branch2a         (Conv2D)
# bn4h_branch2a          (BatchNorm)
# res4h_branch2b         (Conv2D)
# bn4h_branch2b          (BatchNorm)
# res4h_branch2c         (Conv2D)
# bn4h_branch2c          (BatchNorm)
# res4i_branch2a         (Conv2D)
# bn4i_branch2a          (BatchNorm)
# res4i_branch2b         (Conv2D)
# bn4i_branch2b          (BatchNorm)
# res4i_branch2c         (Conv2D)
# bn4i_branch2c          (BatchNorm)
# res4j_branch2a         (Conv2D)
# bn4j_branch2a          (BatchNorm)
# res4j_branch2b         (Conv2D)
# bn4j_branch2b          (BatchNorm)
# res4j_branch2c         (Conv2D)
# bn4j_branch2c          (BatchNorm)
# res4k_branch2a         (Conv2D)
# bn4k_branch2a          (BatchNorm)
# res4k_branch2b         (Conv2D)
# bn4k_branch2b          (BatchNorm)
# res4k_branch2c         (Conv2D)
# bn4k_branch2c          (BatchNorm)
# res4l_branch2a         (Conv2D)
# bn4l_branch2a          (BatchNorm)
# res4l_branch2b         (Conv2D)
# bn4l_branch2b          (BatchNorm)
# res4l_branch2c         (Conv2D)
# bn4l_branch2c          (BatchNorm)
# res4m_branch2a         (Conv2D)
# bn4m_branch2a          (BatchNorm)
# res4m_branch2b         (Conv2D)
# bn4m_branch2b          (BatchNorm)
# res4m_branch2c         (Conv2D)
# bn4m_branch2c          (BatchNorm)
# res4n_branch2a         (Conv2D)
# bn4n_branch2a          (BatchNorm)
# res4n_branch2b         (Conv2D)
# bn4n_branch2b          (BatchNorm)
# res4n_branch2c         (Conv2D)
# bn4n_branch2c          (BatchNorm)
# res4o_branch2a         (Conv2D)
# bn4o_branch2a          (BatchNorm)
# res4o_branch2b         (Conv2D)
# bn4o_branch2b          (BatchNorm)
# res4o_branch2c         (Conv2D)
# bn4o_branch2c          (BatchNorm)
# res4p_branch2a         (Conv2D)
# bn4p_branch2a          (BatchNorm)
# res4p_branch2b         (Conv2D)
# bn4p_branch2b          (BatchNorm)
# res4p_branch2c         (Conv2D)
# bn4p_branch2c          (BatchNorm)
# res4q_branch2a         (Conv2D)
# bn4q_branch2a          (BatchNorm)
# res4q_branch2b         (Conv2D)
# bn4q_branch2b          (BatchNorm)
# res4q_branch2c         (Conv2D)
# bn4q_branch2c          (BatchNorm)
# res4r_branch2a         (Conv2D)
# bn4r_branch2a          (BatchNorm)
# res4r_branch2b         (Conv2D)
# bn4r_branch2b          (BatchNorm)
# res4r_branch2c         (Conv2D)
# bn4r_branch2c          (BatchNorm)
# res4s_branch2a         (Conv2D)
# bn4s_branch2a          (BatchNorm)
# res4s_branch2b         (Conv2D)
# bn4s_branch2b          (BatchNorm)
# res4s_branch2c         (Conv2D)
# bn4s_branch2c          (BatchNorm)
# res4t_branch2a         (Conv2D)
# bn4t_branch2a          (BatchNorm)
# res4t_branch2b         (Conv2D)
# bn4t_branch2b          (BatchNorm)
# res4t_branch2c         (Conv2D)
# bn4t_branch2c          (BatchNorm)
# res4u_branch2a         (Conv2D)
# bn4u_branch2a          (BatchNorm)
# res4u_branch2b         (Conv2D)
# bn4u_branch2b          (BatchNorm)
# res4u_branch2c         (Conv2D)
# bn4u_branch2c          (BatchNorm)
# res4v_branch2a         (Conv2D)
# bn4v_branch2a          (BatchNorm)
# res4v_branch2b         (Conv2D)
# bn4v_branch2b          (BatchNorm)
# res4v_branch2c         (Conv2D)
# bn4v_branch2c          (BatchNorm)
# res4w_branch2a         (Conv2D)
# bn4w_branch2a          (BatchNorm)
# res4w_branch2b         (Conv2D)
# bn4w_branch2b          (BatchNorm)
# res4w_branch2c         (Conv2D)
# bn4w_branch2c          (BatchNorm)
# res5a_branch2a         (Conv2D)
# bn5a_branch2a          (BatchNorm)
# res5a_branch2b         (Conv2D)
# bn5a_branch2b          (BatchNorm)
# res5a_branch2c         (Conv2D)
# res5a_branch1          (Conv2D)
# bn5a_branch2c          (BatchNorm)
# bn5a_branch1           (BatchNorm)
# res5b_branch2a         (Conv2D)
# bn5b_branch2a          (BatchNorm)
# res5b_branch2b         (Conv2D)
# bn5b_branch2b          (BatchNorm)
# res5b_branch2c         (Conv2D)
# bn5b_branch2c          (BatchNorm)
# res5c_branch2a         (Conv2D)
# bn5c_branch2a          (BatchNorm)
# res5c_branch2b         (Conv2D)
# bn5c_branch2b          (BatchNorm)
# res5c_branch2c         (Conv2D)
# bn5c_branch2c          (BatchNorm)
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 4/50
# 150/150 [==============================] - 176s 1s/step - loss: 1.0672 - rpn_class_loss: 0.0152 - rpn_bbox_loss: 0.4184 - mrcnn_class_loss: 0.0076 - mrcnn_bbox_loss: 0.2832 - mrcnn_mask_loss: 0.3429 - val_loss: 1.0475 - val_rpn_class_loss: 0.0089 - val_rpn_bbox_loss: 0.3098 - val_mrcnn_class_loss: 0.0066 - val_mrcnn_bbox_loss: 0.3327 - val_mrcnn_mask_loss: 0.3894
# Epoch 5/50
# 150/150 [==============================] - 102s 680ms/step - loss: 0.8531 - rpn_class_loss: 0.0107 - rpn_bbox_loss: 0.2900 - mrcnn_class_loss: 0.0059 - mrcnn_bbox_loss: 0.2297 - mrcnn_mask_loss: 0.3168 - val_loss: 1.1752 - val_rpn_class_loss: 0.0085 - val_rpn_bbox_loss: 0.4457 - val_mrcnn_class_loss: 0.0030 - val_mrcnn_bbox_loss: 0.3698 - val_mrcnn_mask_loss: 0.3482
# Epoch 6/50
# 150/150 [==============================] - 102s 678ms/step - loss: 0.7478 - rpn_class_loss: 0.0109 - rpn_bbox_loss: 0.1832 - mrcnn_class_loss: 0.0053 - mrcnn_bbox_loss: 0.2127 - mrcnn_mask_loss: 0.3357 - val_loss: 1.1492 - val_rpn_class_loss: 0.0071 - val_rpn_bbox_loss: 0.3954 - val_mrcnn_class_loss: 0.0030 - val_mrcnn_bbox_loss: 0.3638 - val_mrcnn_mask_loss: 0.3799
# Epoch 7/50
# 150/150 [==============================] - 102s 679ms/step - loss: 0.7089 - rpn_class_loss: 0.0071 - rpn_bbox_loss: 0.1896 - mrcnn_class_loss: 0.0044 - mrcnn_bbox_loss: 0.1876 - mrcnn_mask_loss: 0.3202 - val_loss: 0.8900 - val_rpn_class_loss: 0.0412 - val_rpn_bbox_loss: 0.2720 - val_mrcnn_class_loss: 0.0095 - val_mrcnn_bbox_loss: 0.2335 - val_mrcnn_mask_loss: 0.3337
# Epoch 8/50
# 150/150 [==============================] - 102s 679ms/step - loss: 0.7621 - rpn_class_loss: 0.0080 - rpn_bbox_loss: 0.1985 - mrcnn_class_loss: 0.0050 - mrcnn_bbox_loss: 0.2219 - mrcnn_mask_loss: 0.3287 - val_loss: 0.7989 - val_rpn_class_loss: 0.0084 - val_rpn_bbox_loss: 0.2578 - val_mrcnn_class_loss: 0.0036 - val_mrcnn_bbox_loss: 0.2151 - val_mrcnn_mask_loss: 0.3140
# Epoch 9/50
# 150/150 [==============================] - 102s 679ms/step - loss: 0.7560 - rpn_class_loss: 0.0073 - rpn_bbox_loss: 0.1935 - mrcnn_class_loss: 0.0051 - mrcnn_bbox_loss: 0.2014 - mrcnn_mask_loss: 0.3487 - val_loss: 0.9043 - val_rpn_class_loss: 0.0068 - val_rpn_bbox_loss: 0.2173 - val_mrcnn_class_loss: 0.0047 - val_mrcnn_bbox_loss: 0.2974 - val_mrcnn_mask_loss: 0.3780
# Epoch 10/50
# 150/150 [==============================] - 102s 682ms/step - loss: 0.8220 - rpn_class_loss: 0.0077 - rpn_bbox_loss: 0.2496 - mrcnn_class_loss: 0.0055 - mrcnn_bbox_loss: 0.2307 - mrcnn_mask_loss: 0.3285 - val_loss: 0.8614 - val_rpn_class_loss: 0.0051 - val_rpn_bbox_loss: 0.1917 - val_mrcnn_class_loss: 0.0044 - val_mrcnn_bbox_loss: 0.2738 - val_mrcnn_mask_loss: 0.3865
# Epoch 11/50
# 150/150 [==============================] - 102s 680ms/step - loss: 0.6338 - rpn_class_loss: 0.0071 - rpn_bbox_loss: 0.1583 - mrcnn_class_loss: 0.0052 - mrcnn_bbox_loss: 0.1604 - mrcnn_mask_loss: 0.3028 - val_loss: 0.8405 - val_rpn_class_loss: 0.0067 - val_rpn_bbox_loss: 0.2258 - val_mrcnn_class_loss: 0.0053 - val_mrcnn_bbox_loss: 0.2555 - val_mrcnn_mask_loss: 0.3472
# Epoch 12/50
# 150/150 [==============================] - 101s 674ms/step - loss: 0.7342 - rpn_class_loss: 0.0092 - rpn_bbox_loss: 0.1735 - mrcnn_class_loss: 0.0060 - mrcnn_bbox_loss: 0.2022 - mrcnn_mask_loss: 0.3433 - val_loss: 0.8134 - val_rpn_class_loss: 0.0068 - val_rpn_bbox_loss: 0.2388 - val_mrcnn_class_loss: 0.0039 - val_mrcnn_bbox_loss: 0.2269 - val_mrcnn_mask_loss: 0.3370
# Epoch 13/50
# 150/150 [==============================] - 102s 680ms/step - loss: 0.5845 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.1349 - mrcnn_class_loss: 0.0045 - mrcnn_bbox_loss: 0.1460 - mrcnn_mask_loss: 0.2947 - val_loss: 0.8297 - val_rpn_class_loss: 0.0057 - val_rpn_bbox_loss: 0.2604 - val_mrcnn_class_loss: 0.0046 - val_mrcnn_bbox_loss: 0.2623 - val_mrcnn_mask_loss: 0.2968
# Epoch 14/50
# 150/150 [==============================] - 102s 679ms/step - loss: 0.6161 - rpn_class_loss: 0.0065 - rpn_bbox_loss: 0.1407 - mrcnn_class_loss: 0.0053 - mrcnn_bbox_loss: 0.1534 - mrcnn_mask_loss: 0.3102 - val_loss: 0.9702 - val_rpn_class_loss: 0.0090 - val_rpn_bbox_loss: 0.2909 - val_mrcnn_class_loss: 0.0043 - val_mrcnn_bbox_loss: 0.2907 - val_mrcnn_mask_loss: 0.3752
# Epoch 15/50
# 150/150 [==============================] - 102s 682ms/step - loss: 0.5500 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.1242 - mrcnn_class_loss: 0.0042 - mrcnn_bbox_loss: 0.1332 - mrcnn_mask_loss: 0.2838 - val_loss: 0.9649 - val_rpn_class_loss: 0.0048 - val_rpn_bbox_loss: 0.2404 - val_mrcnn_class_loss: 0.0032 - val_mrcnn_bbox_loss: 0.2951 - val_mrcnn_mask_loss: 0.4214
# Epoch 16/50
# 150/150 [==============================] - 103s 686ms/step - loss: 0.5662 - rpn_class_loss: 0.0071 - rpn_bbox_loss: 0.1451 - mrcnn_class_loss: 0.0038 - mrcnn_bbox_loss: 0.1313 - mrcnn_mask_loss: 0.2789 - val_loss: 0.8822 - val_rpn_class_loss: 0.0053 - val_rpn_bbox_loss: 0.2037 - val_mrcnn_class_loss: 0.0041 - val_mrcnn_bbox_loss: 0.2837 - val_mrcnn_mask_loss: 0.3854
# Epoch 17/50
# 150/150 [==============================] - 102s 678ms/step - loss: 0.5130 - rpn_class_loss: 0.0054 - rpn_bbox_loss: 0.1092 - mrcnn_class_loss: 0.0043 - mrcnn_bbox_loss: 0.1191 - mrcnn_mask_loss: 0.2750 - val_loss: 0.8642 - val_rpn_class_loss: 0.0045 - val_rpn_bbox_loss: 0.2257 - val_mrcnn_class_loss: 0.0029 - val_mrcnn_bbox_loss: 0.2752 - val_mrcnn_mask_loss: 0.3559
# Epoch 18/50
# 150/150 [==============================] - 103s 685ms/step - loss: 0.5452 - rpn_class_loss: 0.0034 - rpn_bbox_loss: 0.1226 - mrcnn_class_loss: 0.0039 - mrcnn_bbox_loss: 0.1306 - mrcnn_mask_loss: 0.2846 - val_loss: 0.8499 - val_rpn_class_loss: 0.0061 - val_rpn_bbox_loss: 0.2442 - val_mrcnn_class_loss: 0.0031 - val_mrcnn_bbox_loss: 0.2337 - val_mrcnn_mask_loss: 0.3627
# Epoch 19/50
# 150/150 [==============================] - 102s 681ms/step - loss: 0.5040 - rpn_class_loss: 0.0048 - rpn_bbox_loss: 0.1185 - mrcnn_class_loss: 0.0056 - mrcnn_bbox_loss: 0.1078 - mrcnn_mask_loss: 0.2672 - val_loss: 0.9291 - val_rpn_class_loss: 0.0057 - val_rpn_bbox_loss: 0.1943 - val_mrcnn_class_loss: 0.0049 - val_mrcnn_bbox_loss: 0.3168 - val_mrcnn_mask_loss: 0.4075
# Epoch 20/50
# 150/150 [==============================] - 103s 688ms/step - loss: 0.4815 - rpn_class_loss: 0.0045 - rpn_bbox_loss: 0.0921 - mrcnn_class_loss: 0.0044 - mrcnn_bbox_loss: 0.1128 - mrcnn_mask_loss: 0.2678 - val_loss: 0.6443 - val_rpn_class_loss: 0.0040 - val_rpn_bbox_loss: 0.1589 - val_mrcnn_class_loss: 0.0030 - val_mrcnn_bbox_loss: 0.1726 - val_mrcnn_mask_loss: 0.3058
# Epoch 21/50
# 150/150 [==============================] - 102s 682ms/step - loss: 0.4757 - rpn_class_loss: 0.0039 - rpn_bbox_loss: 0.1107 - mrcnn_class_loss: 0.0043 - mrcnn_bbox_loss: 0.1001 - mrcnn_mask_loss: 0.2567 - val_loss: 0.7804 - val_rpn_class_loss: 0.0052 - val_rpn_bbox_loss: 0.1699 - val_mrcnn_class_loss: 0.0038 - val_mrcnn_bbox_loss: 0.2604 - val_mrcnn_mask_loss: 0.3410
# Epoch 22/50
# 150/150 [==============================] - 103s 684ms/step - loss: 0.4500 - rpn_class_loss: 0.0046 - rpn_bbox_loss: 0.0979 - mrcnn_class_loss: 0.0052 - mrcnn_bbox_loss: 0.0998 - mrcnn_mask_loss: 0.2424 - val_loss: 0.9482 - val_rpn_class_loss: 0.0052 - val_rpn_bbox_loss: 0.2204 - val_mrcnn_class_loss: 0.0036 - val_mrcnn_bbox_loss: 0.2946 - val_mrcnn_mask_loss: 0.4245
# Epoch 23/50
# 150/150 [==============================] - 102s 682ms/step - loss: 0.4201 - rpn_class_loss: 0.0039 - rpn_bbox_loss: 0.0894 - mrcnn_class_loss: 0.0053 - mrcnn_bbox_loss: 0.0855 - mrcnn_mask_loss: 0.2360 - val_loss: 0.9329 - val_rpn_class_loss: 0.0057 - val_rpn_bbox_loss: 0.2064 - val_mrcnn_class_loss: 0.0040 - val_mrcnn_bbox_loss: 0.2826 - val_mrcnn_mask_loss: 0.4341
# Epoch 24/50
# 150/150 [==============================] - 103s 685ms/step - loss: 0.4049 - rpn_class_loss: 0.0025 - rpn_bbox_loss: 0.0807 - mrcnn_class_loss: 0.0042 - mrcnn_bbox_loss: 0.0843 - mrcnn_mask_loss: 0.2332 - val_loss: 0.7906 - val_rpn_class_loss: 0.0061 - val_rpn_bbox_loss: 0.1926 - val_mrcnn_class_loss: 0.0042 - val_mrcnn_bbox_loss: 0.2248 - val_mrcnn_mask_loss: 0.3629
# Epoch 25/50
# 150/150 [==============================] - 102s 683ms/step - loss: 0.3666 - rpn_class_loss: 0.0031 - rpn_bbox_loss: 0.0662 - mrcnn_class_loss: 0.0041 - mrcnn_bbox_loss: 0.0658 - mrcnn_mask_loss: 0.2274 - val_loss: 0.7406 - val_rpn_class_loss: 0.0057 - val_rpn_bbox_loss: 0.2127 - val_mrcnn_class_loss: 0.0053 - val_mrcnn_bbox_loss: 0.1860 - val_mrcnn_mask_loss: 0.3307
# Epoch 26/50
# 150/150 [==============================] - 102s 683ms/step - loss: 0.3698 - rpn_class_loss: 0.0044 - rpn_bbox_loss: 0.0779 - mrcnn_class_loss: 0.0036 - mrcnn_bbox_loss: 0.0712 - mrcnn_mask_loss: 0.2127 - val_loss: 0.6929 - val_rpn_class_loss: 0.0024 - val_rpn_bbox_loss: 0.1779 - val_mrcnn_class_loss: 0.0031 - val_mrcnn_bbox_loss: 0.1909 - val_mrcnn_mask_loss: 0.3186
# Epoch 27/50
# 150/150 [==============================] - 103s 686ms/step - loss: 0.3608 - rpn_class_loss: 0.0038 - rpn_bbox_loss: 0.0792 - mrcnn_class_loss: 0.0040 - mrcnn_bbox_loss: 0.0652 - mrcnn_mask_loss: 0.2086 - val_loss: 0.8692 - val_rpn_class_loss: 0.0041 - val_rpn_bbox_loss: 0.1862 - val_mrcnn_class_loss: 0.0041 - val_mrcnn_bbox_loss: 0.2670 - val_mrcnn_mask_loss: 0.4078
# Epoch 28/50
# 150/150 [==============================] - 103s 687ms/step - loss: 0.3752 - rpn_class_loss: 0.0042 - rpn_bbox_loss: 0.0743 - mrcnn_class_loss: 0.0047 - mrcnn_bbox_loss: 0.0738 - mrcnn_mask_loss: 0.2183 - val_loss: 0.8353 - val_rpn_class_loss: 0.0035 - val_rpn_bbox_loss: 0.2045 - val_mrcnn_class_loss: 0.0046 - val_mrcnn_bbox_loss: 0.2648 - val_mrcnn_mask_loss: 0.3579
# Epoch 29/50
# 150/150 [==============================] - 102s 680ms/step - loss: 0.3682 - rpn_class_loss: 0.0044 - rpn_bbox_loss: 0.0748 - mrcnn_class_loss: 0.0043 - mrcnn_bbox_loss: 0.0689 - mrcnn_mask_loss: 0.2157 - val_loss: 0.8011 - val_rpn_class_loss: 0.0028 - val_rpn_bbox_loss: 0.1766 - val_mrcnn_class_loss: 0.0032 - val_mrcnn_bbox_loss: 0.2331 - val_mrcnn_mask_loss: 0.3853
# Epoch 30/50
# 150/150 [==============================] - 104s 690ms/step - loss: 0.2965 - rpn_class_loss: 0.0038 - rpn_bbox_loss: 0.0499 - mrcnn_class_loss: 0.0036 - mrcnn_bbox_loss: 0.0514 - mrcnn_mask_loss: 0.1878 - val_loss: 0.9221 - val_rpn_class_loss: 0.0088 - val_rpn_bbox_loss: 0.2212 - val_mrcnn_class_loss: 0.0039 - val_mrcnn_bbox_loss: 0.2859 - val_mrcnn_mask_loss: 0.4023
# Epoch 31/50
# 150/150 [==============================] - 102s 682ms/step - loss: 0.2937 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0506 - mrcnn_class_loss: 0.0041 - mrcnn_bbox_loss: 0.0490 - mrcnn_mask_loss: 0.1868 - val_loss: 0.9289 - val_rpn_class_loss: 0.0045 - val_rpn_bbox_loss: 0.2337 - val_mrcnn_class_loss: 0.0031 - val_mrcnn_bbox_loss: 0.2637 - val_mrcnn_mask_loss: 0.4239
# Epoch 32/50
# 150/150 [==============================] - 103s 684ms/step - loss: 0.3251 - rpn_class_loss: 0.0029 - rpn_bbox_loss: 0.0645 - mrcnn_class_loss: 0.0044 - mrcnn_bbox_loss: 0.0592 - mrcnn_mask_loss: 0.1940 - val_loss: 0.8793 - val_rpn_class_loss: 0.0024 - val_rpn_bbox_loss: 0.1994 - val_mrcnn_class_loss: 0.0021 - val_mrcnn_bbox_loss: 0.2355 - val_mrcnn_mask_loss: 0.4399
# Epoch 33/50
# 150/150 [==============================] - 102s 682ms/step - loss: 0.2687 - rpn_class_loss: 0.0027 - rpn_bbox_loss: 0.0441 - mrcnn_class_loss: 0.0037 - mrcnn_bbox_loss: 0.0417 - mrcnn_mask_loss: 0.1764 - val_loss: 0.8054 - val_rpn_class_loss: 0.0030 - val_rpn_bbox_loss: 0.1718 - val_mrcnn_class_loss: 0.0029 - val_mrcnn_bbox_loss: 0.2258 - val_mrcnn_mask_loss: 0.4018
# Epoch 34/50
# 150/150 [==============================] - 104s 692ms/step - loss: 0.3260 - rpn_class_loss: 0.0025 - rpn_bbox_loss: 0.0649 - mrcnn_class_loss: 0.0046 - mrcnn_bbox_loss: 0.0566 - mrcnn_mask_loss: 0.1974 - val_loss: 0.9722 - val_rpn_class_loss: 0.0039 - val_rpn_bbox_loss: 0.1973 - val_mrcnn_class_loss: 0.0035 - val_mrcnn_bbox_loss: 0.2742 - val_mrcnn_mask_loss: 0.4933
# Epoch 35/50
# 150/150 [==============================] - 103s 685ms/step - loss: 0.3187 - rpn_class_loss: 0.0028 - rpn_bbox_loss: 0.0640 - mrcnn_class_loss: 0.0036 - mrcnn_bbox_loss: 0.0625 - mrcnn_mask_loss: 0.1858 - val_loss: 0.9815 - val_rpn_class_loss: 0.0035 - val_rpn_bbox_loss: 0.1894 - val_mrcnn_class_loss: 0.0045 - val_mrcnn_bbox_loss: 0.2748 - val_mrcnn_mask_loss: 0.5092
# Epoch 36/50
# 150/150 [==============================] - 102s 683ms/step - loss: 0.3633 - rpn_class_loss: 0.0035 - rpn_bbox_loss: 0.0792 - mrcnn_class_loss: 0.0052 - mrcnn_bbox_loss: 0.0744 - mrcnn_mask_loss: 0.2009 - val_loss: 0.9545 - val_rpn_class_loss: 0.0036 - val_rpn_bbox_loss: 0.1997 - val_mrcnn_class_loss: 0.0047 - val_mrcnn_bbox_loss: 0.2861 - val_mrcnn_mask_loss: 0.4603
# Epoch 37/50
# 150/150 [==============================] - 103s 686ms/step - loss: 0.2992 - rpn_class_loss: 0.0030 - rpn_bbox_loss: 0.0600 - mrcnn_class_loss: 0.0038 - mrcnn_bbox_loss: 0.0548 - mrcnn_mask_loss: 0.1776 - val_loss: 0.8843 - val_rpn_class_loss: 0.0035 - val_rpn_bbox_loss: 0.2037 - val_mrcnn_class_loss: 0.0036 - val_mrcnn_bbox_loss: 0.2514 - val_mrcnn_mask_loss: 0.4221
# Epoch 38/50
# 150/150 [==============================] - 103s 685ms/step - loss: 0.2908 - rpn_class_loss: 0.0018 - rpn_bbox_loss: 0.0562 - mrcnn_class_loss: 0.0047 - mrcnn_bbox_loss: 0.0483 - mrcnn_mask_loss: 0.1798 - val_loss: 0.8510 - val_rpn_class_loss: 0.0037 - val_rpn_bbox_loss: 0.1898 - val_mrcnn_class_loss: 0.0035 - val_mrcnn_bbox_loss: 0.2395 - val_mrcnn_mask_loss: 0.4145
# Epoch 39/50
# 150/150 [==============================] - 103s 685ms/step - loss: 0.2767 - rpn_class_loss: 0.0027 - rpn_bbox_loss: 0.0473 - mrcnn_class_loss: 0.0037 - mrcnn_bbox_loss: 0.0459 - mrcnn_mask_loss: 0.1771 - val_loss: 0.7835 - val_rpn_class_loss: 0.0037 - val_rpn_bbox_loss: 0.1599 - val_mrcnn_class_loss: 0.0048 - val_mrcnn_bbox_loss: 0.2261 - val_mrcnn_mask_loss: 0.3889
# Epoch 40/50
# 150/150 [==============================] - 103s 687ms/step - loss: 0.2982 - rpn_class_loss: 0.0034 - rpn_bbox_loss: 0.0483 - mrcnn_class_loss: 0.0033 - mrcnn_bbox_loss: 0.0552 - mrcnn_mask_loss: 0.1880 - val_loss: 0.8944 - val_rpn_class_loss: 0.0049 - val_rpn_bbox_loss: 0.1901 - val_mrcnn_class_loss: 0.0041 - val_mrcnn_bbox_loss: 0.2527 - val_mrcnn_mask_loss: 0.4426
# Epoch 41/50
# 150/150 [==============================] - 103s 685ms/step - loss: 0.2772 - rpn_class_loss: 0.0047 - rpn_bbox_loss: 0.0506 - mrcnn_class_loss: 0.0035 - mrcnn_bbox_loss: 0.0467 - mrcnn_mask_loss: 0.1716 - val_loss: 1.0309 - val_rpn_class_loss: 0.0034 - val_rpn_bbox_loss: 0.2451 - val_mrcnn_class_loss: 0.0033 - val_mrcnn_bbox_loss: 0.2999 - val_mrcnn_mask_loss: 0.4792
# Epoch 42/50
# 150/150 [==============================] - 102s 683ms/step - loss: 0.2573 - rpn_class_loss: 0.0042 - rpn_bbox_loss: 0.0499 - mrcnn_class_loss: 0.0034 - mrcnn_bbox_loss: 0.0404 - mrcnn_mask_loss: 0.1594 - val_loss: 1.0034 - val_rpn_class_loss: 0.0034 - val_rpn_bbox_loss: 0.2247 - val_mrcnn_class_loss: 0.0024 - val_mrcnn_bbox_loss: 0.2439 - val_mrcnn_mask_loss: 0.5290
# Epoch 43/50
# 150/150 [==============================] - 102s 682ms/step - loss: 0.2831 - rpn_class_loss: 0.0047 - rpn_bbox_loss: 0.0520 - mrcnn_class_loss: 0.0040 - mrcnn_bbox_loss: 0.0500 - mrcnn_mask_loss: 0.1725 - val_loss: 0.9141 - val_rpn_class_loss: 0.0034 - val_rpn_bbox_loss: 0.1780 - val_mrcnn_class_loss: 0.0032 - val_mrcnn_bbox_loss: 0.2586 - val_mrcnn_mask_loss: 0.4709
# Epoch 44/50
# 150/150 [==============================] - 103s 687ms/step - loss: 0.2329 - rpn_class_loss: 0.0033 - rpn_bbox_loss: 0.0406 - mrcnn_class_loss: 0.0035 - mrcnn_bbox_loss: 0.0338 - mrcnn_mask_loss: 0.1516 - val_loss: 0.9034 - val_rpn_class_loss: 0.0026 - val_rpn_bbox_loss: 0.1789 - val_mrcnn_class_loss: 0.0034 - val_mrcnn_bbox_loss: 0.2536 - val_mrcnn_mask_loss: 0.4649
# Epoch 45/50
# 150/150 [==============================] - 104s 691ms/step - loss: 0.2366 - rpn_class_loss: 0.0019 - rpn_bbox_loss: 0.0425 - mrcnn_class_loss: 0.0026 - mrcnn_bbox_loss: 0.0337 - mrcnn_mask_loss: 0.1559 - val_loss: 0.8057 - val_rpn_class_loss: 0.0032 - val_rpn_bbox_loss: 0.1649 - val_mrcnn_class_loss: 0.0036 - val_mrcnn_bbox_loss: 0.2332 - val_mrcnn_mask_loss: 0.4008
# Epoch 46/50
# 150/150 [==============================] - 103s 689ms/step - loss: 0.2649 - rpn_class_loss: 0.0024 - rpn_bbox_loss: 0.0522 - mrcnn_class_loss: 0.0031 - mrcnn_bbox_loss: 0.0414 - mrcnn_mask_loss: 0.1658 - val_loss: 0.8269 - val_rpn_class_loss: 0.0048 - val_rpn_bbox_loss: 0.1965 - val_mrcnn_class_loss: 0.0030 - val_mrcnn_bbox_loss: 0.2302 - val_mrcnn_mask_loss: 0.3925
# Epoch 47/50
# 150/150 [==============================] - 102s 682ms/step - loss: 0.2181 - rpn_class_loss: 0.0019 - rpn_bbox_loss: 0.0379 - mrcnn_class_loss: 0.0023 - mrcnn_bbox_loss: 0.0315 - mrcnn_mask_loss: 0.1445 - val_loss: 0.9743 - val_rpn_class_loss: 0.0047 - val_rpn_bbox_loss: 0.2099 - val_mrcnn_class_loss: 0.0030 - val_mrcnn_bbox_loss: 0.2503 - val_mrcnn_mask_loss: 0.5064
# Epoch 48/50
# 150/150 [==============================] - 104s 691ms/step - loss: 0.2457 - rpn_class_loss: 0.0025 - rpn_bbox_loss: 0.0466 - mrcnn_class_loss: 0.0031 - mrcnn_bbox_loss: 0.0341 - mrcnn_mask_loss: 0.1594 - val_loss: 1.1095 - val_rpn_class_loss: 0.0053 - val_rpn_bbox_loss: 0.2159 - val_mrcnn_class_loss: 0.0032 - val_mrcnn_bbox_loss: 0.3128 - val_mrcnn_mask_loss: 0.5722
# Epoch 49/50
# 150/150 [==============================] - 103s 688ms/step - loss: 0.2071 - rpn_class_loss: 0.0023 - rpn_bbox_loss: 0.0345 - mrcnn_class_loss: 0.0032 - mrcnn_bbox_loss: 0.0299 - mrcnn_mask_loss: 0.1372 - val_loss: 0.8782 - val_rpn_class_loss: 0.0020 - val_rpn_bbox_loss: 0.1645 - val_mrcnn_class_loss: 0.0025 - val_mrcnn_bbox_loss: 0.2293 - val_mrcnn_mask_loss: 0.4799
# Epoch 50/50
# 150/150 [==============================] - 104s 695ms/step - loss: 0.2170 - rpn_class_loss: 0.0032 - rpn_bbox_loss: 0.0368 - mrcnn_class_loss: 0.0033 - mrcnn_bbox_loss: 0.0275 - mrcnn_mask_loss: 0.1462 - val_loss: 0.8209 - val_rpn_class_loss: 0.0025 - val_rpn_bbox_loss: 0.1430 - val_mrcnn_class_loss: 0.0045 - val_mrcnn_bbox_loss: 0.2245 - val_mrcnn_mask_loss: 0.4464

# %%
class InferenceConfig(MarkConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

inference_config = InferenceConfig()

# Recreate the model in inference mode
model = modellib.MaskRCNN(mode="inference", 
                          config=inference_config,
                          model_dir=MODEL_DIR)

# Get path to saved weights
# Either set a specific path or find last trained weights
# model_path = os.path.join(ROOT_DIR, ".h5 file name here")
# model_path = model.find_last()[1]

# Load trained weights (fill in path to trained weights here)
assert model_path != "", "Provide path to trained weights"
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)
# Out:
# WARNING:tensorflow:From ./mrcnn/model.py:772: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Loading weights from  alignment_50.h5

# %%
# Test on a random image
image_id = random.choice(dataset_val.image_ids)
original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
    modellib.load_image_gt(dataset_val, inference_config, 
                           image_id, use_mini_mask=False)

log("original_image", original_image)
log("image_meta", image_meta)
log("gt_class_id", gt_class_id)
log("gt_bbox", gt_bbox)
log("gt_mask", gt_mask)

visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id, 
                            dataset_train.class_names, figsize=(8, 8))
# Out:
# original_image           shape: (1024, 1024, 3)       min:    0.00000  max:   51.00000  uint8
# image_meta               shape: (14,)                 min:    0.00000  max: 2688.00000  float64
# gt_class_id              shape: (1,)                  min:    1.00000  max:    1.00000  int32
# gt_bbox                  shape: (1, 4)                min:  404.00000  max:  462.00000  int32
# gt_mask                  shape: (1024, 1024, 1)       min:    0.00000  max:    1.00000  bool

# %%
results = model.detect([original_image], verbose=1)

r = results[0]
visualize.display_instances(original_image, r['rois'], r['masks'], r['class_ids'], 
                            dataset_val.class_names, r['scores'], ax=get_ax())
# Out:
# Processing 1 images
# image                    shape: (1024, 1024, 3)       min:    0.00000  max:   51.00000  uint8
# molded_images            shape: (1, 1024, 1024, 3)    min: -123.70000  max:  -52.90000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1024.00000  int64
# anchors                  shape: (1, 261888, 4)        min:   -0.35390  max:    1.29134  float32
